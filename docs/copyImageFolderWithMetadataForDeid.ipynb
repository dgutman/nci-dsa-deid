# %%
## Given a full path in the DSA it will copy files so they can be run through the deIdentification pipeline
import girder_client
# %load_ext autoreload
# %autoreload 2
import deidHelpers as hlprs
import dsaSecrets as ds

gc = girder_client.GirderClient(apiUrl=ds.dsaApiUrl)
_ = gc.authenticate(apiKey=ds.dsaApiToken)

# %%
## For testing this will delete images from previous testing
hlprs.cleanupFoldersByPath(gc,hlprs.wsiDeidFolderPathsForCleanup)
# Out:
# Deleted 50 items and 0 folders in folder Unfiled
# Deleted 0 items and 0 folders in folder Redacted
# Deleted 0 items and 0 folders in folder Import Job Reports
# Deleted 0 items and 0 folders in folder Redacted
# Deleted 0 items and 0 folders in folder Approved

# %%
import pandas as pd
metadataFile = "DeId_exampleData_052423.csv"
targetFolder = '646276df3bf3da34495c1268'
sampleImageFolder = '6477c00e309a9ffde6689635'


def createSyntheticDataSetFromCSV( gc, sampleImageFolder, targetFolder, metadataFile):
    """ This will grab a random image from the sample Image Folder, and copy it to the targetFolder
    and will also rename it during this process so it matches whatever was in the metadataFile"""

    sampleImageSet = [x for x in gc.listItem(sampleImageFolder) if "(" not in x['name']]

    
    df = pd.read_csv(metadataFile)
    for k,r in enumerate(df.to_dict(orient='records')):
        ## Copy item and rename it into new target folder
        itemCopy = gc.post(f'item/{sampleImageSet[k]["_id"]}/copy?folderId={targetFolder}&name={r["CASE"]}')
        gc.addMetadataToItem(itemCopy["_id"],{"deidUpload":r})

# %%
createSyntheticDataSetFromCSV(gc, sampleImageFolder, targetFolder, metadataFile)

# %%
df = pd.read_csv(metadataFile)
df.head()

requiredColumns =  ['InputFileName','SampleID','REPOSITORY','STUDY','PROJECT','CASE','BLOCK','ASSAY','INDEX','ImageID',
 'OutputFileName']

# CAse = Patient more or less
# Sample = uniqueish slide #

## Clean Initial Input File

df['InputFileName'] = df.CASE
df['OutputFileName'] = df.CASE +'.deid.svs'

df['SampleID'] = df.CASE.str.extract(r'(TI\d+)')
df['ImageID'] = df.CASE.str.extract(r'00(\d+)_')




# df['CASE'].apply(lambda x: re.sub(r'[\n\r]*','', str(x)))
df = df[requiredColumns]

df.head()
# Out:
#                         InputFileName SampleID REPOSITORY    STUDY  \
# 0  copySlide-0033444_TI02289 4003.svs  TI02289       DCEG  MR-0700
# 1  copySlide-0033445_TI02263 4002.svs  TI02263       DCEG  MR-0700
# 2  copySlide-0033446_TI01978 4003.svs  TI01978       DCEG  MR-0700
# 3  copySlide-0033447_TI02678 4002.svs  TI02678       DCEG  MR-0700
# 4  copySlide-0033448_TI02740 4002.svs  TI02740       DCEG  MR-0700
#
#       PROJECT                                CASE    BLOCK ASSAY  INDEX  \
# 0  HP0700-012  copySlide-0033444_TI02289 4003.svs   BR6011   H&E      1
# 1  HP0700-012  copySlide-0033445_TI02263 4002.svs  BR6011a   H&E      1
# 2  HP0700-012  copySlide-0033446_TI01978 4003.svs   BR6013   H&E      1
# 3  HP0700-012  copySlide-0033447_TI02678 4002.svs   BR6014   H&E      1
# 4  HP0700-012  copySlide-0033448_TI02740 4002.svs   BR6015   H&E      1
#
#   ImageID                               OutputFileName
# 0   33444  copySlide-0033444_TI02289 4003.svs.deid.svs
# 1   33445  copySlide-0033445_TI02263 4002.svs.deid.svs
# 2   33446  copySlide-0033446_TI01978 4003.svs.deid.svs
# 3   33447  copySlide-0033447_TI02678 4002.svs.deid.svs
# 4   33448  copySlide-0033448_TI02740 4002.svs.deid.svs

# %%
# df.to_csv("sampleDeIdFile.csv",index=False
# df.to_dict(orient='records')

# %%
dsaPathToDeid = "/testHALO_import/DCEG/n100 AI"   ## Folder I want to copy over for deidentification

importFolderName = "/WSI DeID/Unfiled"  ## This is for internal bookkeeping, Will be hidden

folderToImport = gc.get(f'resource/lookup?path=/collection{dsaPathToDeid}')

# %%
unfiledImageFolder = gc.get(f'resource/lookup?path=/collection/WSI DeID/Unfiled')
for i in gc.listItem(folderToImport['_id']):

    #### AAH SO THE UNFILED OPERATION IS A MOVE EVENT, NOT A COPY EVENT... SO I NEED TO FIRST COPY THEM TO UNFILED
    ### AND THEN RUN THIS COMMAND TO AVOID MOVING THE ORIGINAL ITEMS...
    ## Using a helper function to generate some random synthetic data
    #imageMeta = hlprs.generate_random_data(hlprs.syntheticData)

    imageMeta = df.loc[df.InputFileName==i['name']].to_dict(orient='record')[0]

    itemCopyToUnfiled = gc.post(f'item/{i["_id"]}/copy?folderId={unfiledImageFolder["_id"]}')
    gc.addMetadataToItem(itemCopyToUnfiled['_id'],{"deidUpload": imageMeta})

    #Will use the refill API endpoint to copy these images to the target directory, and also rename
#     newImageName = f'{imageMeta["PatientID"]}_{imageMeta["BLOCK"]}.{imageMeta["INDEX"]}_WSIDEID'
    newImageName = imageMeta['OutputFileName']

    newImagePath = f'/WSI DeID/AvailableToProcess/{imageMeta["SampleID"]}/{newImageName}.svs'
    ## TO DO: ADD File Path Extension programatiicaly
    ## See if an image with this name already exists in the AvailableToProcess folder.. this throws an error

    try:
        print("Trying to process item",newImageName,"which I think should go to",newImagePath)
        itemCopyOutput = gc.put(f'/wsi_deid/item/{itemCopyToUnfiled["_id"]}/action/refile?imageId={newImageName}&tokenId={imageMeta["SampleID"]}')

        deidMeta = {**itemCopyOutput["meta"]["deidUpload"], **imageMeta}
    #     print(deidMeta)
        gc.addMetadataToItem(itemCopyOutput["_id"],{"deidUpload":deidMeta})
        print("Adding a new item for",imageMeta['PatientID'])
    except:
        print("Item already exists...")
# Out:
# /tmp/ipykernel_97335/3644917886.py:9: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   imageMeta = df.loc[df.InputFileName==i['name']].to_dict(orient='record')[0]
# Trying to process item copySlide-0033444_TI02289 4003.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI02289/copySlide-0033444_TI02289 4003.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0033445_TI02263 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI02263/copySlide-0033445_TI02263 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0033446_TI01978 4003.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI01978/copySlide-0033446_TI01978 4003.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0033447_TI02678 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI02678/copySlide-0033447_TI02678 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0033448_TI02740 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI02740/copySlide-0033448_TI02740 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0034756_TI02294 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI02294/copySlide-0034756_TI02294 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0
4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI05739/copySlide-0043765_TI05739 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043766_TI05739 4003.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI05739/copySlide-0043766_TI05739 4003.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043767_TI05740 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI05740/copySlide-0043767_TI05740 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043768_TI05740 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI05740/copySlide-0043768_TI05740 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043769_TI05740 4003.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI05740/copySlide-0043769_TI05740 4003.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043770_TI05741 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI05741/copySlide-0043770_TI05741 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043771_TI05741 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI05741/copySlide-0043771_TI05741 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043772_TI05741 4003.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI05741/copySlide-0043772_TI05741 4003.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043773_TI05742 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI05742/copySlide-0043773_TI05742 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043774_TI06034 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06034/copySlide-0043774_TI06034 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043775_TI06034 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06034/copySlide-0043775_TI06034 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043776_TI06034 4003.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06034/copySlide-0043776_TI06034 4003.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043777_TI06035 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06035/copySlide-0043777_TI06035 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043778_TI06035 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06035/copySlide-0043778_TI06035 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043779_TI06035 4003.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06035/copySlide-0043779_TI06035 4003.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043780_TI06035 4004.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06035/copySlide-0043780_TI06035 4004.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043781_TI06036 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06036/copySlide-0043781_TI06036 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043782_TI06036 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06036/copySlide-0043782_TI06036 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043783_TI06037 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06037/copySlide-0043783_TI06037 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043784_TI06037 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06037/copySlide-0043784_TI06037 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043785_TI06037 4003.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06037/copySlide-0043785_TI06037 4003.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043786_TI06038 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06038/copySlide-0043786_TI06038 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043787_TI06039 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06039/copySlide-0043787_TI06039 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043788_TI06039 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06039/copySlide-0043788_TI06039 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043789_TI06039 4003.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06039/copySlide-0043789_TI06039 4003.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043790_TI06039 4004.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06039/copySlide-0043790_TI06039 4004.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043791_TI06040 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06040/copySlide-0043791_TI06040 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043917_TI06371 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06371/copySlide-0043917_TI06371 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043918_TI06371 4003.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06371/copySlide-0043918_TI06371 4003.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043919_TI06372 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06372/copySlide-0043919_TI06372 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043920_TI06372 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06372/copySlide-0043920_TI06372 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043921_TI06373 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06373/copySlide-0043921_TI06373 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043922_TI06374 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06374/copySlide-0043922_TI06374 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043923_TI06374 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06374/copySlide-0043923_TI06374 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043924_TI06374 4003.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06374/copySlide-0043924_TI06374 4003.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043925_TI06375 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06375/copySlide-0043925_TI06375 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043926_TI06375 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06375/copySlide-0043926_TI06375 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043927_TI06377 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06377/copySlide-0043927_TI06377 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043928_TI06377 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06377/copySlide-0043928_TI06377 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043929_TI06378 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06378/copySlide-0043929_TI06378 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043930_TI06378 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06378/copySlide-0043930_TI06378 4002.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043931_TI06378 4003.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06378/copySlide-0043931_TI06378 4003.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043932_TI06379 4001.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06379/copySlide-0043932_TI06379 4001.svs.deid.svs.svs
# Item already exists...
# Trying to process item copySlide-0043933_TI06379 4002.svs.deid.svs which I think should go to /WSI DeID/AvailableToProcess/TI06379/copySlide-0043933_TI06379 4002.svs.deid.svs.svs
# Item already exists...

# %%
# for i in gc.listItem(folderToImport['_id']):
#     print(i['name'])
i['name']

# %%
# get(f'resource/lookup?path=/collection/WSI DeID/AvailableToProcess/Patient3/Patient3_5.1_WSIDEID.svs')
df.loc[df.InputFileName=='copySlide-0033444_TI02289 4003.svs'].to_dict(orient='record')[0]
